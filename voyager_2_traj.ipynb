# %%
from astropy import units as u
from astropy import time
import astropy
import numpy as np

from poliastro import iod
from poliastro.bodies import Body,Mars, Earth, Venus, Jupiter, Saturn, Uranus, Neptune, Sun, Europa, Ganymede, Callisto, Io, Titan
from poliastro.ephem import Ephem
from poliastro.maneuver import Maneuver
from poliastro.twobody import Orbit
from poliastro.util import time_range
from poliastro.frames import Planes
from poliastro.frames.fixed import JupiterFixed
from poliastro.frames.equatorial import JupiterICRS
from astroquery.jplhorizons import Horizons
from copy import deepcopy

from scipy import ndimage
from scipy.spatial.transform import Rotation as scipyRot

from poliastro.plotting import OrbitPlotter3D, StaticOrbitPlotter
import math
import matplotlib.pyplot as plt
# More info: https://plotly.com/python/renderers/
import plotly.io as pio
from poliastro.util import norm, time_range
pio.renderers.default = "plotly_mimetype+notebook_connected"
import weakref
from astropy.coordinates import solar_system_ephemeris
from collections.abc import Mapping

solar_system_ephemeris.set("jpl")
# Out:
# <ScienceState solar_system_ephemeris: 'jpl'>

# %%
# plotter = StaticOrbitPlotter(plane=Planes.EARTH_ECLIPTIC)

def find_assist_periapsis_bounds(dep_num,sling_bod_orb,inc_orb_vel,date):
    sling_body=planet_order[dep_num]
    target_body = planet_order[dep_num+1]

    #relative velocity & speed to body we are slingshotting around
    rel_vel = inc_orb_vel-sling_bod_orb.rv()[1]
    rel_sped = np.linalg.norm(rel_vel)
    
    r_ps = sling_body.R+np.geomspace(r_p_min,r_p_max,num=int(assist_transit_resolution/2))*u.km
    
    rot_angs=2*np.arcsin(1/((r_ps*rel_sped*rel_sped/sling_body.k)+1*u.one))
    #Now check if these (in plane) rotations lead to an orbit that reaches the target body
    target_body_debug_orbit = Orbit.from_ephem(Sun,ephem_order[dep_num+1],date)
    
    axis = np.array([0,0,1.0])   #rotate in ecliptic plane intitially
    min_dv=1000000*u.km/u.s
    target_arrival_date=None

    for sign in [-1,1]:
        for i in range(len(rot_angs)):
            rot = scipyRot.from_rotvec(axis*rot_angs[i])
            rel_vel_out= rot.apply(rel_vel.value) * u.km/u.s
            test_orb = Orbit.from_vectors(Sun,sling_bod_orb.r,rel_vel_out+sling_bod_orb.rv()[1],date)
            #check if apogee of new orbit reaches target, or is hyperbolic
            #Note, does not work for gravity assists to bodies in lower orbits,
            #Thus will need changes for Jovian grand tour
            if (test_orb.r_a.value>target_body_debug_orbit.r_a.value and test_orb.ecc <1 or test_orb.ecc>1):
                # print(f"Success at closest approach of {r_ps[i].to(u.km):.2f} to {sling_body} on {date}")
                #find time to reach
                time_to_next=0
                reached_next_bod=False
                test_orb_prop=test_orb.propagate(0*u.day)
                while not reached_next_bod:
                    test_orb_prop=test_orb_prop.propagate(5*u.day)
                    time_to_next += 5*u.day
                    if np.linalg.norm(test_orb_prop.rv()[0]).value > target_body_debug_orbit.a.value:
                        reached_next_bod=True
                rough_arrival_date = date+time_to_next
                # print(f"Arrival at {target_body} at roughly {rough_arrival_date}")
                target_arrival_orb = Orbit.from_ephem(Sun,ephem_order[dep_num+1],rough_arrival_date)   
                #Now evaluate lambert to target body
                man_lambert = Maneuver.lambert(sling_bod_orb, target_arrival_orb)
                lambert_test_orb=sling_bod_orb.apply_maneuver(man_lambert,intermediate=True)[0]
                # print(lambert_test_orb.r)
                # print(sling_bod_orb.r)
                # print(test_orb.r)
                speed_dif=abs(np.linalg.norm((lambert_test_orb.rv()[1]-sling_bod_orb.rv()[1])) - np.linalg.norm((test_orb.rv()[1]-sling_bod_orb.rv()[1])))
                if speed_dif < min_dv:
                    # print(min_dv)
                    min_dv=speed_dif
                    target_arrival_date=deepcopy(rough_arrival_date)
                # print(f"Minimum DV {speed_dif.to(u.km/u.s):.2f}")

            # else:
            #     print("failure")
    # print(f"It takes {min_dv} to reach {target_body.name} arriving at {target_arrival_date}")
    # print(f"Trying to arrive at {target_body.name} on {target_arrival_date}")
    target_arrival_orb = Orbit.from_ephem(Sun, ephem_order[dep_num + 1], target_arrival_date)
    man_lambert = Maneuver.lambert(sling_bod_orb, target_arrival_orb)
    outgoing_orb = sling_bod_orb.apply_maneuver(man_lambert, intermediate=True)[0]
    
    # plotter.plot(target_arrival_orb, label=f"{target_body.name} Orbit")
    # plotter.plot(outgoing_orb, label=f"Post-Assist Orbit")
    # plotter.plot(sling_bod_orb, label=f"{sling_body.name} Orbit")
    return min_dv, target_arrival_date, outgoing_orb

# %%
#search for viable Earth-Jupiter transit
resolution=7#days
min_tof=400#days
max_tof=800#days

assist_transit_resolution = 80 #number of periapsis values to scan over for viablish slingshots

#max and min flyby distances
r_p_min=50000
r_p_max=950000

first_date=time.Time("1976-09-05 00:01", scale="utc").tdb
arb_extra_date = time.Time("1977-11-05 00:01", scale="utc").tdb
buffer = 100*u.day

final_date=time.Time("1990-10-01 00:01", scale="utc").tdb



# ephem_earth=Ephem.from_horizons("399", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_jupiter=Ephem.from_horizons("599", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_saturn=Ephem.from_horizons("699", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_uranus=Ephem.from_horizons("799", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_neptune=Ephem.from_horizons("899", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)


ephem_earth = Ephem.from_body(Earth, time_range(first_date,end=arb_extra_date+max_tof+buffer,periods=300),plane=Planes.EARTH_ECLIPTIC)
ephem_jupiter = Ephem.from_body(Jupiter, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_saturn = Ephem.from_body(Saturn, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_uranus = Ephem.from_body(Uranus, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_neptune = Ephem.from_body(Neptune, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
planet_order=[Earth, Jupiter, Saturn, Uranus, Neptune]
ephem_order = [ephem_earth, ephem_jupiter, ephem_saturn, ephem_uranus, ephem_neptune]
# Out:
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
# plotter = StaticOrbitPlotter()

#Delete below when done testing
voyager_orbits=[]
planet_orbits=[]
flybys_dates=[]

found_grand_tour=False
#Delete above

total_scans=0
total_viable_ejects=0
dv_maneuvers_total=0
arrive_bod_1=None
orb_after_1=None

tof_range=np.arange(min_tof,max_tof,resolution)*u.day
launch_dates = time_range(start=first_date, end=arb_extra_date,periods=100)


# launch_date=time.Time("1977-08-30 18:43:24.514", scale="utc").tdb
# tof=688*u.day

for launch_date in launch_dates:
    for tof in tof_range:
        arrive_date=launch_date+tof

        earth_orb = Orbit.from_ephem(Sun, ephem_earth, launch_date)
        jupiter_orb = Orbit.from_ephem(Sun, ephem_jupiter, arrive_date)
        man_lambert = Maneuver.lambert(earth_orb, jupiter_orb, M=0)
        # print(man_lambert[0])
        ej_dv= np.linalg.norm(man_lambert[0][1].value)
        #viable transit found
        total_scans+=1
        if ej_dv < 11000:#roughly what Titan IV could do
            print(f"Found Earth-Jupiter transit with DV {ej_dv*u.km/u.s:.2f} on launch {launch_date} arriving {arrive_date} with transit time {tof.to(u.day):.0f}")
            trans_orb, final_orb = earth_orb.apply_maneuver(man_lambert, intermediate=True)
            launch_orbit=deepcopy(trans_orb)
            voyager_orbits.append(launch_orbit)
            trans_orb=trans_orb.propagate(tof)
            test_orb=jupiter_orb
            test_v=trans_orb.rv()[1]
            test_launch=launch_date
            test_epoch=arrive_date
            total_viable_ejects+=1
            
            
            
            dv_maneuvers_total,arrive_bod_2_date, orb_after_1=find_assist_periapsis_bounds(1,jupiter_orb,trans_orb.rv()[1],arrive_date)
            assist_1=deepcopy(orb_after_1)
            voyager_orbits.append(assist_1)
            flybys_dates.append(arrive_date)
            planet_orbits.append(jupiter_orb)
            
            print(dv_maneuvers_total)
            if(dv_maneuvers_total<100*u.m/u.s):
                print(f"Viable assist at {arrive_date} with {planet_order[1]} to {planet_order[2]} arrving at {arrive_bod_2_date}.")
                bod_2_arriv_orb=orb_after_1.propagate(arrive_bod_2_date)
                bod_2_orb=Orbit.from_ephem(Sun, ephem_order[2], arrive_bod_2_date)
                next_dv,arrive_bod_3_date,orb_after_2=find_assist_periapsis_bounds(2,bod_2_orb,bod_2_arriv_orb.rv()[1],arrive_bod_2_date)
                assist_2=deepcopy(orb_after_2)
                voyager_orbits.append(assist_2)
                flybys_dates.append(arrive_bod_2_date)
                planet_orbits.append(bod_2_orb)
                
                if(next_dv<500*u.m/u.s):
                    print(f"Viable 2nd assist arriving at {planet_order[3]} on {arrive_bod_3_date} with {next_dv.to(u.m/u.s)} at {planet_order[2]} at {arrive_bod_2_date}")
                    bod_3_arriv_orb=orb_after_2.propagate(arrive_bod_3_date)
                    bod_3_orb=Orbit.from_ephem(Sun, ephem_order[3], arrive_bod_3_date)
                    final_dv,arrive_bod_4_date,orb_after_3=find_assist_periapsis_bounds(3,bod_3_orb,bod_3_arriv_orb.rv()[1],arrive_bod_3_date)
                    if(final_dv<100*u.m/u.s):
                        print(f"Viable 3rd assist arriving at {planet_order[4]} on {arrive_bod_4_date} with {final_dv.to(u.m/u.s)} on {planet_order[3]} at {arrive_bod_3_date}")
                        assist_3=deepcopy(orb_after_3)
                        voyager_orbits.append(assist_3)
                        flybys_dates.append(arrive_bod_3_date)
                        planet_orbits.append(bod_3_orb)
                        body_4_orb=Orbit.from_ephem(Sun, ephem_order[4], arrive_bod_4_date)
                        planet_orbits.append(body_4_orb)
                        print("GRAND TOUR FOUND!")
                        print(f"Leave Earth {launch_date}, arrive at Jupiter on{arrive_date} , assist 2 with Saturn on {arrive_bod_2_date} , assist 3 with Uranus {arrive_bod_3_date} (Saturn-Uranus), arrive at Neptune at {arrive_bod_4_date}")
                        found_grand_tour=True
                        break
                        
                    else:
                        print("No viable 3rd assist")
                else:
                    print("No viable 2nd assist")
        if(found_grand_tour):
            break
        
            
            
            
print(f"Scanned over {total_scans} trajectories from {planet_order[0]} to {planet_order[1]}")
print(f"Found {total_viable_ejects} viable ejects")
# Out:
# Found Earth-Jupiter transit with DV 10998.99 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-03-20 05:50:53.445 with transit time 582 d
# 1018.7233005667804 km / d
# Viable assist at 1979-03-20 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-24 05:50:53.445.
# 1018.7233005667804 km / d
# Viable assist at 1979-03-20 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-24 05:50:53.445.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10937.16 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-03-27 05:50:53.445 with transit time 589 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10937.16 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-03-27 05:50:53.445 with transit time 589 d
# 3359.060915504815 km / d
# Viable assist at 1979-03-27 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-10 05:50:53.445.
# 3359.060915504815 km / d
# Viable assist at 1979-03-27 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-10 05:50:53.445.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10881.30 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-03 05:50:53.445 with transit time 596 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10881.30 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-03 05:50:53.445 with transit time 596 d
# 1206.1191360458033 km / d
# Viable assist at 1979-04-03 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-22 05:50:53.445.
# 1206.1191360458033 km / d
# Viable assist at 1979-04-03 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-22 05:50:53.445.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10831.64 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-10 05:50:53.445 with transit time 603 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10831.64 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-10 05:50:53.445 with transit time 603 d
# 2773.2293740410823 km / d
# Viable assist at 1979-04-10 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-08 05:50:53.445.
# 2773.2293740410823 km / d
# Viable assist at 1979-04-10 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-08 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1984-11-14 05:50:53.445 with 333.0514868019317 m / s at Saturn (♄) at 1981-02-08 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1984-11-14 05:50:53.445 with 333.0514868019317 m / s at Saturn (♄) at 1981-02-08 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10788.52 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-17 05:50:53.445 with transit time 610 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10788.52 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-17 05:50:53.445 with transit time 610 d
# 1640.5731750611449 km / d
# Viable assist at 1979-04-17 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-20 05:50:53.445.
# 1640.5731750611449 km / d
# Viable assist at 1979-04-17 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-20 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1984-12-16 05:50:53.445 with 205.61994849260103 m / s at Saturn (♄) at 1981-02-20 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1984-12-16 05:50:53.445 with 205.61994849260103 m / s at Saturn (♄) at 1981-02-20 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10752.43 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-24 05:50:53.445 with transit time 617 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10752.43 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-04-24 05:50:53.445 with transit time 617 d
# 1982.455766081228 km / d
# Viable assist at 1979-04-24 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-09 05:50:53.445.
# 1982.455766081228 km / d
# Viable assist at 1979-04-24 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-09 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-01 05:50:53.445 with 53.39729434283206 m / s at Saturn (♄) at 1981-03-09 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-01 05:50:53.445 with 53.39729434283206 m / s at Saturn (♄) at 1981-03-09 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10724.03 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-01 05:50:53.445 with transit time 624 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10724.03 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-01 05:50:53.445 with transit time 624 d
# 2266.825096880202 km / d
# Viable assist at 1979-05-01 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-21 05:50:53.445.
# 2266.825096880202 km / d
# Viable assist at 1979-05-01 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-21 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-23 05:50:53.445 with 57.78835694395335 m / s at Saturn (♄) at 1981-03-21 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-23 05:50:53.445 with 57.78835694395335 m / s at Saturn (♄) at 1981-03-21 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10704.23 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-08 05:50:53.445 with transit time 631 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10704.23 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-08 05:50:53.445 with transit time 631 d
# 1054.9383027723525 km / d
# Viable assist at 1979-05-08 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-07 05:50:53.445.
# 1054.9383027723525 km / d
# Viable assist at 1979-05-08 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-07 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-01 05:50:53.445 with 32.279015704819656 m / s at Saturn (♄) at 1981-04-07 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-01 05:50:53.445 with 32.279015704819656 m / s at Saturn (♄) at 1981-04-07 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10694.25 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-15 05:50:53.445 with transit time 638 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10694.25 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-15 05:50:53.445 with transit time 638 d
# 2995.853411889635 km / d
# Viable assist at 1979-05-15 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-19 05:50:53.445.
# 2995.853411889635 km / d
# Viable assist at 1979-05-15 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-19 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-28 05:50:53.445 with 19.057912292825037 m / s at Saturn (♄) at 1981-04-19 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-28 05:50:53.445 with 19.057912292825037 m / s at Saturn (♄) at 1981-04-19 05:50:53.445
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10695.75 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-22 05:50:53.445 with transit time 645 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10695.75 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-22 05:50:53.445 with transit time 645 d
# 104.51459682255518 km / d
# Viable assist at 1979-05-22 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-06 05:50:53.445.
# 104.51459682255518 km / d
# Viable assist at 1979-05-22 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-06 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-06-04 05:50:53.445 with 41.27741907947725 m / s at Saturn (♄) at 1981-05-06 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-06-04 05:50:53.445 with 41.27741907947725 m / s at Saturn (♄) at 1981-05-06 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1988-09-16 05:50:53.445 with 95.94262443637018 m / s on Uranus (⛢) at 1985-06-04 05:50:53.445
# Found Earth-Jupiter transit with DV 10710.99 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-29 05:50:53.445 with transit time 652 d
# Viable 3rd assist arriving at Neptune (♆) on 1988-09-16 05:50:53.445 with 95.94262443637018 m / s on Uranus (⛢) at 1985-06-04 05:50:53.445
# Found Earth-Jupiter transit with DV 10710.99 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-05-29 05:50:53.445 with transit time 652 d
# 3005.4258040044224 km / d
# Viable assist at 1979-05-29 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-23 05:50:53.445.
# 3005.4258040044224 km / d
# Viable assist at 1979-05-29 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-23 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-11 05:50:53.445 with 62.38317881840851 m / s at Saturn (♄) at 1981-05-23 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-11 05:50:53.445 with 62.38317881840851 m / s at Saturn (♄) at 1981-05-23 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1988-11-12 05:50:53.445 with 37.0043043358439 m / s on Uranus (⛢) at 1985-07-11 05:50:53.445
# Found Earth-Jupiter transit with DV 10743.09 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-05 05:50:53.445 with transit time 659 d
# Viable 3rd assist arriving at Neptune (♆) on 1988-11-12 05:50:53.445 with 37.0043043358439 m / s on Uranus (⛢) at 1985-07-11 05:50:53.445
# Found Earth-Jupiter transit with DV 10743.09 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-05 05:50:53.445 with transit time 659 d
# 668.4846731967991 km / d
# Viable assist at 1979-06-05 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-04 05:50:53.445.
# 668.4846731967991 km / d
# Viable assist at 1979-06-05 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-04 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-28 05:50:53.445 with 4.839557497558686 m / s at Saturn (♄) at 1981-06-04 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-28 05:50:53.445 with 4.839557497558686 m / s at Saturn (♄) at 1981-06-04 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1988-12-09 05:50:53.445 with 32.10435827933974 m / s on Uranus (⛢) at 1985-07-28 05:50:53.445
# Found Earth-Jupiter transit with DV 10796.41 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-12 05:50:53.445 with transit time 666 d
# Viable 3rd assist arriving at Neptune (♆) on 1988-12-09 05:50:53.445 with 32.10435827933974 m / s on Uranus (⛢) at 1985-07-28 05:50:53.445
# Found Earth-Jupiter transit with DV 10796.41 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-12 05:50:53.445 with transit time 666 d
# 2246.298790783738 km / d
# Viable assist at 1979-06-12 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-21 05:50:53.445.
# 2246.298790783738 km / d
# Viable assist at 1979-06-12 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-21 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-08-29 05:50:53.445 with 24.077491224820225 m / s at Saturn (♄) at 1981-06-21 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-08-29 05:50:53.445 with 24.077491224820225 m / s at Saturn (♄) at 1981-06-21 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1989-01-20 05:50:53.445 with 12.081197565467273 m / s on Uranus (⛢) at 1985-08-29 05:50:53.445
# Found Earth-Jupiter transit with DV 10877.13 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-19 05:50:53.445 with transit time 673 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-01-20 05:50:53.445 with 12.081197565467273 m / s on Uranus (⛢) at 1985-08-29 05:50:53.445
# Found Earth-Jupiter transit with DV 10877.13 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-19 05:50:53.445 with transit time 673 d
# 886.4234770335024 km / d
# Viable assist at 1979-06-19 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-03 05:50:53.445.
# 886.4234770335024 km / d
# Viable assist at 1979-06-19 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-03 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-09-30 05:50:53.445 with 69.97419075162152 m / s at Saturn (♄) at 1981-07-03 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-09-30 05:50:53.445 with 69.97419075162152 m / s at Saturn (♄) at 1981-07-03 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1989-03-08 05:50:53.445 with 21.683973938467076 m / s on Uranus (⛢) at 1985-09-30 05:50:53.445
# Found Earth-Jupiter transit with DV 10994.24 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-26 05:50:53.445 with transit time 680 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-03-08 05:50:53.445 with 21.683973938467076 m / s on Uranus (⛢) at 1985-09-30 05:50:53.445
# Found Earth-Jupiter transit with DV 10994.24 km / s on launch 1977-08-15 05:50:53.445 arriving 1979-06-26 05:50:53.445 with transit time 680 d
# 2369.5190284479177 km / d
# Viable assist at 1979-06-26 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-20 05:50:53.445.
# 2369.5190284479177 km / d
# Viable assist at 1979-06-26 05:50:53.445 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-20 05:50:53.445.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-10-22 05:50:53.445 with 55.37998699710577 m / s at Saturn (♄) at 1981-07-20 05:50:53.445
# Viable 2nd assist arriving at Uranus (⛢) on 1985-10-22 05:50:53.445 with 55.37998699710577 m / s at Saturn (♄) at 1981-07-20 05:50:53.445
# Viable 3rd assist arriving at Neptune (♆) on 1989-04-09 05:50:53.445 with 28.92086930376805 m / s on Uranus (⛢) at 1985-10-22 05:50:53.445
# Found Earth-Jupiter transit with DV 10961.88 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-02-17 13:07:15.274 with transit time 547 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-04-09 05:50:53.445 with 28.92086930376805 m / s on Uranus (⛢) at 1985-10-22 05:50:53.445
# Found Earth-Jupiter transit with DV 10961.88 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-02-17 13:07:15.274 with transit time 547 d
# 1379.3490659710951 km / d
# Viable assist at 1979-02-17 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-10-19 13:07:15.274.
# 1379.3490659710951 km / d
# Viable assist at 1979-02-17 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-10-19 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10875.19 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-02-24 13:07:15.274 with transit time 554 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10875.19 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-02-24 13:07:15.274 with transit time 554 d
# 3938.9715362985153 km / d
# Viable assist at 1979-02-24 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-11-05 13:07:15.274.
# 3938.9715362985153 km / d
# Viable assist at 1979-02-24 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-11-05 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10793.59 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-03 13:07:15.274 with transit time 561 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10793.59 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-03 13:07:15.274 with transit time 561 d
# 1101.3546738248551 km / d
# Viable assist at 1979-03-03 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-11-17 13:07:15.274.
# 1101.3546738248551 km / d
# Viable assist at 1979-03-03 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-11-17 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10716.93 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-10 13:07:15.274 with transit time 568 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10716.93 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-10 13:07:15.274 with transit time 568 d
# 3732.7981965526706 km / d
# Viable assist at 1979-03-10 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-04 13:07:15.274.
# 3732.7981965526706 km / d
# Viable assist at 1979-03-10 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-04 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10645.06 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-17 13:07:15.274 with transit time 575 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10645.06 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-17 13:07:15.274 with transit time 575 d
# 1155.313092376804 km / d
# Viable assist at 1979-03-17 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-16 13:07:15.274.
# 1155.313092376804 km / d
# Viable assist at 1979-03-17 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1980-12-16 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10577.88 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-24 13:07:15.274 with transit time 582 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10577.88 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-24 13:07:15.274 with transit time 582 d
# 3220.399664029712 km / d
# Viable assist at 1979-03-24 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-02 13:07:15.274.
# 3220.399664029712 km / d
# Viable assist at 1979-03-24 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-02 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10515.28 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-31 13:07:15.274 with transit time 589 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10515.28 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-03-31 13:07:15.274 with transit time 589 d
# 1533.1381713114679 km / d
# Viable assist at 1979-03-31 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-14 13:07:15.274.
# 1533.1381713114679 km / d
# Viable assist at 1979-03-31 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-14 13:07:15.274.
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10457.22 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-07 13:07:15.274 with transit time 596 d
# No viable 2nd assist
# Found Earth-Jupiter transit with DV 10457.22 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-07 13:07:15.274 with transit time 596 d
# 2409.102654694696 km / d
# Viable assist at 1979-04-07 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-31 13:07:15.274.
# 2409.102654694696 km / d
# Viable assist at 1979-04-07 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-01-31 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1984-10-22 13:07:15.274 with 422.3354613554774 m / s at Saturn (♄) at 1981-01-31 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1984-10-22 13:07:15.274 with 422.3354613554774 m / s at Saturn (♄) at 1981-01-31 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10403.65 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-14 13:07:15.274 with transit time 603 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10403.65 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-14 13:07:15.274 with transit time 603 d
# 2223.853859302122 km / d
# Viable assist at 1979-04-14 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-12 13:07:15.274.
# 2223.853859302122 km / d
# Viable assist at 1979-04-14 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-02-12 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1984-11-23 13:07:15.274 with 290.26892671535916 m / s at Saturn (♄) at 1981-02-12 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1984-11-23 13:07:15.274 with 290.26892671535916 m / s at Saturn (♄) at 1981-02-12 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10354.57 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-21 13:07:15.274 with transit time 610 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10354.57 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-21 13:07:15.274 with transit time 610 d
# 1310.07365781907 km / d
# Viable assist at 1979-04-21 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-01 13:07:15.274.
# 1310.07365781907 km / d
# Viable assist at 1979-04-21 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-01 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-01-09 13:07:15.274 with 132.14800151874778 m / s at Saturn (♄) at 1981-03-01 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-01-09 13:07:15.274 with 132.14800151874778 m / s at Saturn (♄) at 1981-03-01 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10310.04 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-28 13:07:15.274 with transit time 617 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10310.04 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-04-28 13:07:15.274 with transit time 617 d
# 3212.045421157847 km / d
# Viable assist at 1979-04-28 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-13 13:07:15.274.
# 3212.045421157847 km / d
# Viable assist at 1979-04-28 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-13 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-10 13:07:15.274 with 15.239567714557374 m / s at Saturn (♄) at 1981-03-13 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-02-10 13:07:15.274 with 15.239567714557374 m / s at Saturn (♄) at 1981-03-13 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10270.13 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-05 13:07:15.274 with transit time 624 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10270.13 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-05 13:07:15.274 with transit time 624 d
# 59.834237257018685 km / d
# Viable assist at 1979-05-05 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-30 13:07:15.274.
# 59.834237257018685 km / d
# Viable assist at 1979-05-05 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-03-30 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-03-19 13:07:15.274 with 9.007898751701253 m / s at Saturn (♄) at 1981-03-30 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-03-19 13:07:15.274 with 9.007898751701253 m / s at Saturn (♄) at 1981-03-30 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10235.00 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-12 13:07:15.274 with transit time 631 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10235.00 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-12 13:07:15.274 with transit time 631 d
# 2767.983479836257 km / d
# Viable assist at 1979-05-12 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-16 13:07:15.274.
# 2767.983479836257 km / d
# Viable assist at 1979-05-12 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-16 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-25 13:07:15.274 with 32.11196377877193 m / s at Saturn (♄) at 1981-04-16 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-04-25 13:07:15.274 with 32.11196377877193 m / s at Saturn (♄) at 1981-04-16 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10204.85 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-19 13:07:15.274 with transit time 638 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10204.85 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-19 13:07:15.274 with transit time 638 d
# 1675.2572383024963 km / d
# Viable assist at 1979-05-19 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-28 13:07:15.274.
# 1675.2572383024963 km / d
# Viable assist at 1979-05-19 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-04-28 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-05-12 13:07:15.274 with 28.559383840728074 m / s at Saturn (♄) at 1981-04-28 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-05-12 13:07:15.274 with 28.559383840728074 m / s at Saturn (♄) at 1981-04-28 13:07:15.274
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10179.99 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-26 13:07:15.274 with transit time 645 d
# No viable 3rd assist
# Found Earth-Jupiter transit with DV 10179.99 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-05-26 13:07:15.274 with transit time 645 d
# 826.7197745608864 km / d
# Viable assist at 1979-05-26 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-15 13:07:15.274.
# 826.7197745608864 km / d
# Viable assist at 1979-05-26 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-05-15 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-06-18 13:07:15.274 with 5.0751786062459425 m / s at Saturn (♄) at 1981-05-15 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-06-18 13:07:15.274 with 5.0751786062459425 m / s at Saturn (♄) at 1981-05-15 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1988-10-05 13:07:15.274 with 92.64916355847768 m / s on Uranus (⛢) at 1985-06-18 13:07:15.274
# Found Earth-Jupiter transit with DV 10160.80 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-02 13:07:15.274 with transit time 652 d
# Viable 3rd assist arriving at Neptune (♆) on 1988-10-05 13:07:15.274 with 92.64916355847768 m / s on Uranus (⛢) at 1985-06-18 13:07:15.274
# Found Earth-Jupiter transit with DV 10160.80 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-02 13:07:15.274 with transit time 652 d
# 3050.1817294661887 km / d
# Viable assist at 1979-06-02 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-01 13:07:15.274.
# 3050.1817294661887 km / d
# Viable assist at 1979-06-02 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-01 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-20 13:07:15.274 with 34.717589195015194 m / s at Saturn (♄) at 1981-06-01 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-07-20 13:07:15.274 with 34.717589195015194 m / s at Saturn (♄) at 1981-06-01 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1988-11-26 13:07:15.274 with 15.242638302321817 m / s on Uranus (⛢) at 1985-07-20 13:07:15.274
# Found Earth-Jupiter transit with DV 10147.82 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-09 13:07:15.274 with transit time 659 d
# Viable 3rd assist arriving at Neptune (♆) on 1988-11-26 13:07:15.274 with 15.242638302321817 m / s on Uranus (⛢) at 1985-07-20 13:07:15.274
# Found Earth-Jupiter transit with DV 10147.82 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-09 13:07:15.274 with transit time 659 d
# 1282.1407754630782 km / d
# Viable assist at 1979-06-09 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-13 13:07:15.274.
# 1282.1407754630782 km / d
# Viable assist at 1979-06-09 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-13 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-08-21 13:07:15.274 with 62.74719280433971 m / s at Saturn (♄) at 1981-06-13 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-08-21 13:07:15.274 with 62.74719280433971 m / s at Saturn (♄) at 1981-06-13 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1989-01-12 13:07:15.274 with 6.175162256918998 m / s on Uranus (⛢) at 1985-08-21 13:07:15.274
# Found Earth-Jupiter transit with DV 10141.75 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-16 13:07:15.274 with transit time 666 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-01-12 13:07:15.274 with 6.175162256918998 m / s on Uranus (⛢) at 1985-08-21 13:07:15.274
# Found Earth-Jupiter transit with DV 10141.75 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-16 13:07:15.274 with transit time 666 d
# 687.4701576124644 km / d
# Viable assist at 1979-06-16 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-30 13:07:15.274.
# 687.4701576124644 km / d
# Viable assist at 1979-06-16 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-06-30 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-09-12 13:07:15.274 with 66.43604019130348 m / s at Saturn (♄) at 1981-06-30 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-09-12 13:07:15.274 with 66.43604019130348 m / s at Saturn (♄) at 1981-06-30 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1989-02-08 13:07:15.274 with 11.560392833004395 m / s on Uranus (⛢) at 1985-09-12 13:07:15.274
# Found Earth-Jupiter transit with DV 10143.50 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-23 13:07:15.274 with transit time 673 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-02-08 13:07:15.274 with 11.560392833004395 m / s on Uranus (⛢) at 1985-09-12 13:07:15.274
# Found Earth-Jupiter transit with DV 10143.50 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-23 13:07:15.274 with transit time 673 d
# 2435.45730382693 km / d
# Viable assist at 1979-06-23 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-17 13:07:15.274.
# 2435.45730382693 km / d
# Viable assist at 1979-06-23 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-17 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-10-29 13:07:15.274 with 52.596014721800906 m / s at Saturn (♄) at 1981-07-17 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-10-29 13:07:15.274 with 52.596014721800906 m / s at Saturn (♄) at 1981-07-17 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1989-04-21 13:07:15.274 with 9.358229185357533 m / s on Uranus (⛢) at 1985-10-29 13:07:15.274
# Found Earth-Jupiter transit with DV 10154.30 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-30 13:07:15.274 with transit time 680 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-04-21 13:07:15.274 with 9.358229185357533 m / s on Uranus (⛢) at 1985-10-29 13:07:15.274
# Found Earth-Jupiter transit with DV 10154.30 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-06-30 13:07:15.274 with transit time 680 d
# 1706.4200754861813 km / d
# Viable assist at 1979-06-30 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-29 13:07:15.274.
# 1706.4200754861813 km / d
# Viable assist at 1979-06-30 13:07:15.274 with Jupiter (♃) to Saturn (♄) arrving at 1981-07-29 13:07:15.274.
# Viable 2nd assist arriving at Uranus (⛢) on 1985-11-15 13:07:15.274 with 0.31607520877177764 m / s at Saturn (♄) at 1981-07-29 13:07:15.274
# Viable 2nd assist arriving at Uranus (⛢) on 1985-11-15 13:07:15.274 with 0.31607520877177764 m / s at Saturn (♄) at 1981-07-29 13:07:15.274
# Viable 3rd assist arriving at Neptune (♆) on 1989-05-13 13:07:15.274 with 1.9938341043625432 m / s on Uranus (⛢) at 1985-11-15 13:07:15.274
# Found Earth-Jupiter transit with DV 10175.72 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-07-07 13:07:15.274 with transit time 687 d
# Viable 3rd assist arriving at Neptune (♆) on 1989-05-13 13:07:15.274 with 1.9938341043625432 m / s on Uranus (⛢) at 1985-11-15 13:07:15.274
# Found Earth-Jupiter transit with DV 10175.72 km / s on launch 1977-08-19 13:07:15.274 arriving 1979-07-07 13:07:15.274 with transit time 687 d
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 49
#      44 test_epoch=arrive_date
#      45 total_viable_ejects+=1
# ---> 49 dv_maneuvers_total,arrive_bod_2_date, orb_after_1=find_assist_periapsis_bounds(1,jupiter_orb,trans_orb.rv()[1],arrive_date)
#      50 assist_1=deepcopy(orb_after_1)
#      51 voyager_orbits.append(assist_1)
#
# Cell In[2], line 42, in find_assist_periapsis_bounds(dep_num, sling_bod_orb, inc_orb_vel, date)
#      40 rough_arrival_date = date+time_to_next
#      41 # print(f"Arrival at {target_body} at roughly {rough_arrival_date}")
# ---> 42 target_arrival_orb = Orbit.from_ephem(Sun,ephem_order[dep_num+1],rough_arrival_date)
#      43 #Now evaluate lambert to target body
#      44 man_lambert = Maneuver.lambert(sling_bod_orb, target_arrival_orb)
#
# File ~/Documents/github/poliastro-jack/src/poliastro/twobody/orbit/creation.py:242, in OrbitCreationMixin.from_ephem(cls, attractor, ephem, epoch)
#     224 @classmethod
#     225 def from_ephem(cls, attractor, ephem, epoch):
#     226     """Create osculating orbit from ephemerides at a given epoch.
#     227
#     228     This will assume that the `Ephem` coordinates
#    (...)
#     239
#     240     """
#     241     return cls.from_vectors(
# --> 242         attractor, *ephem.rv(epoch), epoch, ephem.plane
#     243     )
#
# File ~/Documents/github/poliastro-jack/src/poliastro/ephem.py:368, in Ephem.rv(self, epochs, **kwargs)
#     357 def rv(self, epochs=None, **kwargs):
#     358     """Position and velocity vectors at given epochs.
#     359
#     360     Parameters
#    (...)
#     366
#     367     """
# --> 368     coordinates = self.sample(epochs, **kwargs)
#     370     r = coordinates.get_xyz(xyz_axis=1)
#     371     v = coordinates.differentials["s"].get_d_xyz(xyz_axis=1)
#
# File ~/Documents/github/poliastro-jack/src/poliastro/ephem.py:349, in Ephem.sample(self, epochs, interpolator)
#     346 if epochs is None or epochs.isscalar and (epochs == self.epochs).all():
#     347     return self._coordinates
# --> 349 coordinates = interpolator.interpolate(
#     350     epochs.reshape(-1),
#     351     self.epochs,
#     352     self._coordinates,
#     353 )
#     355 return coordinates
#
# File ~/Documents/github/poliastro-jack/src/poliastro/ephem.py:106, in SplineInterpolator.interpolate(self, epochs, reference_epochs, coordinates)
#     102 xyz_unit = coordinates.xyz.unit
#     103 d_xyz_unit = coordinates.differentials["s"].d_xyz.unit
#     105 result_xyz = (
# --> 106     spline_interp(
#     107         coordinates.xyz.value,
#     108         reference_epochs.jd,
#     109         epochs.jd,
#     110         kind=self._kind,
#     111     )
#     112     << xyz_unit
#     113 )
#     114 result_d_xyz = (
#     115     spline_interp(
#     116         coordinates.differentials["s"].d_xyz.value,
#    (...)
#     121     << d_xyz_unit
#     122 )
#     124 return CartesianRepresentation(
#     125     result_xyz, differentials=CartesianDifferential(result_d_xyz)
#     126 )
#
# File ~/Documents/github/poliastro-jack/src/poliastro/_math/interpolate.py:9, in spline_interp(y, x, u, kind)
#       7 def spline_interp(y, x, u, *, kind="cubic"):
#       8     """Interpolates y, sampled at x instants, at u instants using `scipy.interpolate.interp1d`."""
# ----> 9     y_u = interp1d(x, y, kind=kind)(u)
#      10     return y_u
#
# File ~/Documents/miniforge3-n/envs/cleanastronomy/lib/python3.10/site-packages/scipy/interpolate/interpolate.py:474, in interp1d.__init__(self, x, y, kind, axis, copy, bounds_error, fill_value, assume_sorted)
#     472 # Interpolation goes internally along the first axis
#     473 self.y = y
# --> 474 self._y = self._reshape_yi(self.y)
#     475 self.x = x
#     476 del y, x  # clean up namespace to prevent misuse; use attributes
#
# File ~/Documents/miniforge3-n/envs/cleanastronomy/lib/python3.10/site-packages/scipy/interpolate/polyint.py:110, in _Interpolator1D._reshape_yi(self, yi, check)
#     107     ok_shape = "%r + (N,) + %r" % (self._y_extra_shape[-self._y_axis:],
#     108                                    self._y_extra_shape[:-self._y_axis])
#     109     raise ValueError("Data must be of shape %s" % ok_shape)
# --> 110 return yi.reshape((yi.shape[0], -1))
#
# KeyboardInterrupt:

# %%
plotter = StaticOrbitPlotter(dark=False)

# Plot all voyager orbits
for i, vo in enumerate(voyager_orbits):
    plotter.plot(vo, label=f"Transit between {planet_order[i].name} and {planet_order[i+1].name}")
    # print(f"Transit between {planet_order[i].name} and {planet_order[i+1].name}'}")

# Plot all planet orbits at encounter times
for i, po in enumerate(planet_orbits):
    plotter.plot(po, label=f"{planet_order[i+1].name} at encounter")
    
# Get the matplotlib Axes (poliastro versions differ: ax vs _ax)
ax = getattr(plotter, "ax", None) or plotter._ax

# Example: zoom to a +/- 5e8 km box around (0,0)
range=5e9
ax.set_xlim(-range, range)
ax.set_ylim(-range, range)
ax.set_aspect("equal", adjustable="box")

plt.show()

# %%
# 1977-09-01 18:43:24.514 1979-06-22 18:43:24.514 11889.144703103324 km / s
time_1 = time.Time("1977-08-20 18:43:24.514", scale="utc").tdb
time_2 = time.Time("1979-06-09 18:43:24.514", scale="utc").tdb
time_3 = time.Time("1994-08-25 04:00:00", scale="utc").tdb

ephem_earth = Ephem.from_body(Earth, time_range(time_1, end=time_2), plane=Planes.EARTH_ECLIPTIC)
ephem_jupiter = Ephem.from_body(Jupiter, time_range(time_1, end=time_2), plane=Planes.EARTH_ECLIPTIC)


earth_orb = Orbit.from_ephem(Sun, ephem_earth, time_1)
jupiter_orb = Orbit.from_ephem(Sun, ephem_jupiter, time_2)
man_lambert = Maneuver.lambert(earth_orb, jupiter_orb)      
ej_dv= np.linalg.norm(man_lambert[0][1].value)
print(ej_dv*u.km/u.s)
# Out:
# 10034.059925508496 km / s
