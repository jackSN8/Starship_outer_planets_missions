# %%
from astropy import units as u
from astropy import time
import astropy
import numpy as np

from poliastro import iod
from poliastro.bodies import Body,Mars, Earth, Venus, Jupiter, Saturn, Uranus, Neptune, Sun, Europa, Ganymede, Callisto, Io, Titan
from poliastro.ephem import Ephem
from poliastro.maneuver import Maneuver
from poliastro.twobody import Orbit
from poliastro.util import time_range
from poliastro.frames import Planes
from poliastro.frames.fixed import JupiterFixed
from poliastro.frames.equatorial import JupiterICRS
from astroquery.jplhorizons import Horizons
from copy import deepcopy

from scipy import ndimage
from scipy.spatial.transform import Rotation as scipyRot

from poliastro.plotting import OrbitPlotter3D, StaticOrbitPlotter
import math
import matplotlib.pyplot as plt
# More info: https://plotly.com/python/renderers/
import plotly.io as pio
from poliastro.util import norm, time_range
pio.renderers.default = "plotly_mimetype+notebook_connected"
import weakref
from astropy.coordinates import solar_system_ephemeris
from collections.abc import Mapping

solar_system_ephemeris.set("jpl")
# Out:
# <ScienceState solar_system_ephemeris: 'jpl'>

# %%
# plotter = StaticOrbitPlotter(plane=Planes.EARTH_ECLIPTIC)

def find_assist_periapsis_bounds(dep_num,sling_bod_orb,inc_orb_vel,date):
    sling_body=planet_order[dep_num]
    target_body = planet_order[dep_num+1]

    #relative velocity & speed to body we are slingshotting around
    rel_vel = inc_orb_vel-sling_bod_orb.rv()[1]
    rel_sped = np.linalg.norm(rel_vel)
    
    r_ps = sling_body.R+np.geomspace(r_p_min,r_p_max,num=int(assist_transit_resolution/2))*u.km
    
    rot_angs=2*np.arcsin(1/((r_ps*rel_sped*rel_sped/sling_body.k)+1*u.one))
    #Now check if these (in plane) rotations lead to an orbit that reaches the target body
    target_body_debug_orbit = Orbit.from_ephem(Sun,ephem_order[dep_num+1],date)
    
    axis = np.array([0,0,1.0])   #rotate in ecliptic plane intitially
    min_dv=1000000*u.km/u.s
    target_arrival_date=None

    for sign in [-1,1]:
        for i in range(len(rot_angs)):
            rot = scipyRot.from_rotvec(axis*rot_angs[i])
            rel_vel_out= rot.apply(rel_vel.value) * u.km/u.s
            test_orb = Orbit.from_vectors(Sun,sling_bod_orb.r,rel_vel_out+sling_bod_orb.rv()[1],date)
            #check if apogee of new orbit reaches target, or is hyperbolic
            #Note, does not work for gravity assists to bodies in lower orbits,
            #Thus will need changes for Jovian grand tour
            if (test_orb.r_a.value>target_body_debug_orbit.r_a.value and test_orb.ecc <1 or test_orb.ecc>1):
                # print(f"Success at closest approach of {r_ps[i].to(u.km):.2f} to {sling_body} on {date}")
                #find time to reach
                time_to_next=0
                reached_next_bod=False
                test_orb_prop=test_orb.propagate(0*u.day)
                while not reached_next_bod:
                    test_orb_prop=test_orb_prop.propagate(5*u.day)
                    time_to_next += 5*u.day
                    if np.linalg.norm(test_orb_prop.rv()[0]).value > target_body_debug_orbit.a.value:
                        reached_next_bod=True
                rough_arrival_date = date+time_to_next
                # print(f"Arrival at {target_body} at roughly {rough_arrival_date}")
                target_arrival_orb = Orbit.from_ephem(Sun,ephem_order[dep_num+1],rough_arrival_date)   
                #Now evaluate lambert to target body
                man_lambert = Maneuver.lambert(sling_bod_orb, target_arrival_orb)
                lambert_test_orb=sling_bod_orb.apply_maneuver(man_lambert,intermediate=True)[0]
                # print(lambert_test_orb.r)
                # print(sling_bod_orb.r)
                # print(test_orb.r)
                speed_dif=abs(np.linalg.norm((lambert_test_orb.rv()[1]-sling_bod_orb.rv()[1])) - np.linalg.norm((test_orb.rv()[1]-sling_bod_orb.rv()[1])))
                if speed_dif < min_dv:
                    # print(min_dv)
                    min_dv=speed_dif
                    target_arrival_date=deepcopy(rough_arrival_date)
                # print(f"Minimum DV {speed_dif.to(u.km/u.s):.2f}")

            # else:
            #     print("failure")
    # print(f"It takes {min_dv} to reach {target_body.name} arriving at {target_arrival_date}")
    # print(f"Trying to arrive at {target_body.name} on {target_arrival_date}")
    target_arrival_orb = Orbit.from_ephem(Sun, ephem_order[dep_num + 1], target_arrival_date)
    man_lambert = Maneuver.lambert(sling_bod_orb, target_arrival_orb)
    outgoing_orb = sling_bod_orb.apply_maneuver(man_lambert, intermediate=True)[0]
    
    # plotter.plot(target_arrival_orb, label=f"{target_body.name} Orbit")
    # plotter.plot(outgoing_orb, label=f"Post-Assist Orbit")
    # plotter.plot(sling_bod_orb, label=f"{sling_body.name} Orbit")
    return min_dv, target_arrival_date, outgoing_orb

# %%
#search for viable Earth-Jupiter transit
resolution=7#days
min_tof=400#days
max_tof=800#days

assist_transit_resolution = 80 #number of periapsis values to scan over for viablish slingshots

#max and min flyby distances
r_p_min=50000
r_p_max=950000

first_date=time.Time("2030-09-05 00:01", scale="utc").tdb
arb_extra_date = time.Time("2040-11-05 00:01", scale="utc").tdb
buffer = 100*u.day

final_date=time.Time("2043-10-01 00:01", scale="utc").tdb



# ephem_earth=Ephem.from_horizons("399", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_jupiter=Ephem.from_horizons("599", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_saturn=Ephem.from_horizons("699", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_uranus=Ephem.from_horizons("799", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)
# ephem_neptune=Ephem.from_horizons("899", time_range(first_date,end=final_date),plane=Planes.EARTH_ECLIPTIC)


ephem_earth = Ephem.from_body(Earth, time_range(first_date,end=arb_extra_date+max_tof+buffer,periods=300),plane=Planes.EARTH_ECLIPTIC)
ephem_jupiter = Ephem.from_body(Jupiter, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_saturn = Ephem.from_body(Saturn, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_uranus = Ephem.from_body(Uranus, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
ephem_neptune = Ephem.from_body(Neptune, time_range(first_date,end=final_date,periods=1000),plane=Planes.EARTH_ECLIPTIC)
planet_order=[Earth, Jupiter, Saturn]#, Uranus, Neptune]
ephem_order = [ephem_earth, ephem_jupiter, ephem_saturn]#, ephem_uranus, ephem_neptune]
# Out:
# /home/jack/Documents/miniforge3-n/envs/cleanastronomy/lib/python3.10/site-packages/erfa/core.py:133: ErfaWarning:
#
# ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#
# /home/jack/Documents/miniforge3-n/envs/cleanastronomy/lib/python3.10/site-packages/erfa/core.py:133: ErfaWarning:
#
# ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#
# /home/jack/Documents/miniforge3-n/envs/cleanastronomy/lib/python3.10/site-packages/erfa/core.py:133: ErfaWarning:
#
# ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#
# WARNING: TimeDeltaMissingUnitWarning: Numerical value without unit or explicit format passed to TimeDelta, assuming days [astropy.time.core]

# %%
# plotter = StaticOrbitPlotter()

#Delete below when done testing

found_grand_tour=False
#Delete above

total_scans=0
total_viable_ejects=0
assist_1_count=0
assist_2_count=0


dv_maneuvers_total=0
arrive_bod_1=None
orb_after_1=None

tof_range=np.arange(min_tof,max_tof,resolution)*u.day
launch_dates = time_range(start=first_date, end=arb_extra_date,periods=100)


# launch_date=time.Time("1977-08-30 18:43:24.514", scale="utc").tdb
# tof=688*u.day

for launch_date in launch_dates:
    for tof in tof_range:
        arrive_date=launch_date+tof
        


        earth_orb = Orbit.from_ephem(Sun, ephem_earth, launch_date)
        jupiter_orb = Orbit.from_ephem(Sun, ephem_jupiter, arrive_date)
        man_lambert = Maneuver.lambert(earth_orb, jupiter_orb, M=0)
        # print(man_lambert[0])
        ej_dv= np.linalg.norm(man_lambert[0][1].value)
        #viable transit found
        total_scans+=1
        if ej_dv < 10000:#roughly what Titan IV could do
            print(f"Found Earth-Jupiter transit with DV {ej_dv*u.km/u.s:.2f} on launch {launch_date} arriving {arrive_date} with transit time {tof.to(u.day):.0f}")
            trans_orb, final_orb = earth_orb.apply_maneuver(man_lambert, intermediate=True)
            launch_orbit=deepcopy(trans_orb)
            voyager_orbits.append(launch_orbit)
            trans_orb=trans_orb.propagate(tof)
            test_orb=jupiter_orb
            test_v=trans_orb.rv()[1]
            test_launch=launch_date
            test_epoch=arrive_date
            total_viable_ejects+=1
            
            
            
            dv_maneuvers_total,arrive_bod_2_date, orb_after_1=find_assist_periapsis_bounds(1,jupiter_orb,trans_orb.rv()[1],arrive_date)
            assist_1=deepcopy(orb_after_1)
            voyager_orbits.append(assist_1)
            flybys_dates.append(arrive_date)
            planet_orbits.append(earth_orb)
            planet_orbits.append(jupiter_orb)
            
            # print(dv_maneuvers_total)
            if(dv_maneuvers_total<100*u.m/u.s):
                print(f"Viable assist at {arrive_date} with {planet_order[1]} to {planet_order[2]} arrving at {arrive_bod_2_date}.")
                bod_2_arriv_orb=orb_after_1.propagate(arrive_bod_2_date)
                bod_2_orb=Orbit.from_ephem(Sun, ephem_order[2], arrive_bod_2_date)
                # next_dv,arrive_bod_3_date,orb_after_2=find_assist_periapsis_bounds(2,bod_2_orb,bod_2_arriv_orb.rv()[1],arrive_bod_2_date)
                # assist_2=deepcopy(orb_after_2)
                # voyager_orbits.append(assist_2)
                flybys_dates.append(arrive_bod_2_date)
                planet_orbits.append(bod_2_orb)
                assist_1_count+=1
                found_grand_tour=True
                
                # if(next_dv<100*u.m/u.s):
                #     print(f"Viable 2nd assist arriving at {planet_order[3]} on {arrive_bod_3_date} with {next_dv.to(u.m/u.s)} at {planet_order[2]} at {arrive_bod_2_date}")
                #     bod_3_arriv_orb=orb_after_2.propagate(arrive_bod_3_date)
                #     bod_3_orb=Orbit.from_ephem(Sun, ephem_order[3], arrive_bod_3_date)
                #     assist_2_count+=1
                #     final_dv,arrive_bod_4_date,orb_after_3=find_assist_periapsis_bounds(3,bod_3_orb,bod_3_arriv_orb.rv()[1],arrive_bod_3_date)
                #     if(final_dv<100*u.m/u.s):
                #         print(f"Viable 3rd assist arriving at {planet_order[4]} on {arrive_bod_4_date} with {final_dv.to(u.m/u.s)} on {planet_order[3]} at {arrive_bod_3_date}")
                #         assist_3=deepcopy(orb_after_3)
                #         voyager_orbits.append(assist_3)
                #         flybys_dates.append(arrive_bod_3_date)
                #         planet_orbits.append(bod_3_orb)
                #         body_4_orb=Orbit.from_ephem(Sun, ephem_order[4], arrive_bod_4_date)
                #         planet_orbits.append(body_4_orb)
                #         print("GRAND TOUR FOUND!")
                #         print(f"Leave Earth {launch_date}, arrive at Jupiter on {arrive_date} , assist 2 with Saturn on {arrive_bod_2_date} , assist 3 with Uranus {arrive_bod_3_date}, arrive at Neptune at {arrive_bod_4_date}")
                #         found_grand_tour=True
                #         break
                        
                #     else:
                #         print("No viable 3rd assist")
                # else:
                #     print("No viable 2nd assist")
        if(found_grand_tour):
            break
        else:
            voyager_orbits=[]
            planet_orbits=[]
            flybys_dates=[]
            
            
            
print(f"Scanned over {total_scans} trajectories from {planet_order[0]} to {planet_order[1]}")
print(f"Found {total_viable_ejects} viable ejects from Earth to Jupiter for Titan IV")
print(f"Found {assist_1_count} viable 1st assists from Jupiter to Saturn")
print(f"Found {assist_2_count} viable 2nd assists from Saturn to Uranus")
print(f"Found 1 grand tour!")
# Out:
# Found Earth-Jupiter transit with DV 9983.01 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-02-16 13:51:14.637 with transit time 708 d
# Found Earth-Jupiter transit with DV 9959.20 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-02-23 13:51:14.637 with transit time 715 d
# Found Earth-Jupiter transit with DV 9935.57 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-03-02 13:51:14.637 with transit time 722 d
# Found Earth-Jupiter transit with DV 9912.13 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-03-09 13:51:14.637 with transit time 729 d
# Found Earth-Jupiter transit with DV 9888.87 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-03-16 13:51:14.637 with transit time 736 d
# Found Earth-Jupiter transit with DV 9865.79 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-03-23 13:51:14.637 with transit time 743 d
# Found Earth-Jupiter transit with DV 9842.90 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-03-30 13:51:14.637 with transit time 750 d
# Found Earth-Jupiter transit with DV 9820.21 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-04-06 13:51:14.637 with transit time 757 d
# Found Earth-Jupiter transit with DV 9797.72 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-04-13 13:51:14.637 with transit time 764 d
# Found Earth-Jupiter transit with DV 9775.47 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-04-20 13:51:14.637 with transit time 771 d
# Found Earth-Jupiter transit with DV 9753.46 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-04-27 13:51:14.637 with transit time 778 d
# Found Earth-Jupiter transit with DV 9731.71 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-05-04 13:51:14.637 with transit time 785 d
# Found Earth-Jupiter transit with DV 9710.27 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-05-11 13:51:14.637 with transit time 792 d
# Found Earth-Jupiter transit with DV 9689.16 km / s on launch 2031-03-11 13:51:14.637 arriving 2033-05-18 13:51:14.637 with transit time 799 d
# Found Earth-Jupiter transit with DV 9955.32 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-09-18 17:29:25.546 with transit time 547 d
# Found Earth-Jupiter transit with DV 9888.46 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-09-25 17:29:25.546 with transit time 554 d
# Found Earth-Jupiter transit with DV 9826.26 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-10-02 17:29:25.546 with transit time 561 d
# Found Earth-Jupiter transit with DV 9768.56 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-10-09 17:29:25.546 with transit time 568 d
# Found Earth-Jupiter transit with DV 9715.22 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-10-16 17:29:25.546 with transit time 575 d
# Found Earth-Jupiter transit with DV 9666.12 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-10-23 17:29:25.546 with transit time 582 d
# Found Earth-Jupiter transit with DV 9621.16 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-10-30 17:29:25.546 with transit time 589 d
# Found Earth-Jupiter transit with DV 9580.27 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-11-06 17:29:25.546 with transit time 596 d
# Found Earth-Jupiter transit with DV 9543.41 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-11-13 17:29:25.546 with transit time 603 d
# Found Earth-Jupiter transit with DV 9510.56 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-11-20 17:29:25.546 with transit time 610 d
# Found Earth-Jupiter transit with DV 9481.72 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-11-27 17:29:25.546 with transit time 617 d
# Found Earth-Jupiter transit with DV 9456.94 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-12-04 17:29:25.546 with transit time 624 d
# Found Earth-Jupiter transit with DV 9436.31 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-12-11 17:29:25.546 with transit time 631 d
# Found Earth-Jupiter transit with DV 9419.96 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-12-18 17:29:25.546 with transit time 638 d
# Found Earth-Jupiter transit with DV 9408.06 km / s on launch 2032-03-20 17:29:25.546 arriving 2033-12-25 17:29:25.546 with transit time 645 d
# Found Earth-Jupiter transit with DV 9400.85 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-01-01 17:29:25.546 with transit time 652 d
# Found Earth-Jupiter transit with DV 9398.66 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-01-08 17:29:25.546 with transit time 659 d
# Found Earth-Jupiter transit with DV 9401.87 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-01-15 17:29:25.546 with transit time 666 d
# Found Earth-Jupiter transit with DV 9411.01 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-01-22 17:29:25.546 with transit time 673 d
# Found Earth-Jupiter transit with DV 9426.71 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-01-29 17:29:25.546 with transit time 680 d
# Found Earth-Jupiter transit with DV 9449.79 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-02-05 17:29:25.546 with transit time 687 d
# Found Earth-Jupiter transit with DV 9481.28 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-02-12 17:29:25.546 with transit time 694 d
# Found Earth-Jupiter transit with DV 9522.49 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-02-19 17:29:25.546 with transit time 701 d
# Found Earth-Jupiter transit with DV 9575.07 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-02-26 17:29:25.546 with transit time 708 d
# Found Earth-Jupiter transit with DV 9641.17 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-03-05 17:29:25.546 with transit time 715 d
# Found Earth-Jupiter transit with DV 9723.56 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-03-12 17:29:25.546 with transit time 722 d
# Found Earth-Jupiter transit with DV 9825.86 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-03-19 17:29:25.546 with transit time 729 d
# Found Earth-Jupiter transit with DV 9952.90 km / s on launch 2032-03-20 17:29:25.546 arriving 2034-03-26 17:29:25.546 with transit time 736 d
# Found Earth-Jupiter transit with DV 9940.51 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-10-08 09:29:25.546 with transit time 519 d
# Found Earth-Jupiter transit with DV 9876.78 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-10-15 09:29:25.546 with transit time 526 d
# Found Earth-Jupiter transit with DV 9816.85 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-10-22 09:29:25.546 with transit time 533 d
# Found Earth-Jupiter transit with DV 9760.49 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-10-29 09:29:25.546 with transit time 540 d
# Found Earth-Jupiter transit with DV 9707.49 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-11-05 09:29:25.546 with transit time 547 d
# Found Earth-Jupiter transit with DV 9657.63 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-11-12 09:29:25.546 with transit time 554 d
# Found Earth-Jupiter transit with DV 9610.73 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-11-19 09:29:25.546 with transit time 561 d
# Found Earth-Jupiter transit with DV 9566.61 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-11-26 09:29:25.546 with transit time 568 d
# Found Earth-Jupiter transit with DV 9525.12 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-12-03 09:29:25.546 with transit time 575 d
# Found Earth-Jupiter transit with DV 9486.11 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-12-10 09:29:25.546 with transit time 582 d
# Found Earth-Jupiter transit with DV 9449.46 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-12-17 09:29:25.546 with transit time 589 d
# Found Earth-Jupiter transit with DV 9415.03 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-12-24 09:29:25.546 with transit time 596 d
# Found Earth-Jupiter transit with DV 9382.72 km / s on launch 2033-05-07 09:29:25.546 arriving 2034-12-31 09:29:25.546 with transit time 603 d
# Found Earth-Jupiter transit with DV 9352.44 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-01-07 09:29:25.546 with transit time 610 d
# Found Earth-Jupiter transit with DV 9324.11 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-01-14 09:29:25.546 with transit time 617 d
# Found Earth-Jupiter transit with DV 9297.64 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-01-21 09:29:25.546 with transit time 624 d
# Found Earth-Jupiter transit with DV 9272.97 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-01-28 09:29:25.546 with transit time 631 d
# Found Earth-Jupiter transit with DV 9250.06 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-02-04 09:29:25.546 with transit time 638 d
# Found Earth-Jupiter transit with DV 9228.85 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-02-11 09:29:25.546 with transit time 645 d
# Found Earth-Jupiter transit with DV 9209.33 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-02-18 09:29:25.546 with transit time 652 d
# Found Earth-Jupiter transit with DV 9191.46 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-02-25 09:29:25.546 with transit time 659 d
# Found Earth-Jupiter transit with DV 9175.24 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-03-04 09:29:25.546 with transit time 666 d
# Found Earth-Jupiter transit with DV 9160.67 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-03-11 09:29:25.546 with transit time 673 d
# Found Earth-Jupiter transit with DV 9147.76 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-03-18 09:29:25.546 with transit time 680 d
# Found Earth-Jupiter transit with DV 9136.56 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-03-25 09:29:25.546 with transit time 687 d
# Found Earth-Jupiter transit with DV 9127.09 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-04-01 09:29:25.546 with transit time 694 d
# Found Earth-Jupiter transit with DV 9119.42 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-04-08 09:29:25.546 with transit time 701 d
# Found Earth-Jupiter transit with DV 9113.63 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-04-15 09:29:25.546 with transit time 708 d
# Found Earth-Jupiter transit with DV 9109.81 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-04-22 09:29:25.546 with transit time 715 d
# Found Earth-Jupiter transit with DV 9108.09 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-04-29 09:29:25.546 with transit time 722 d
# Found Earth-Jupiter transit with DV 9108.63 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-05-06 09:29:25.546 with transit time 729 d
# Found Earth-Jupiter transit with DV 9111.59 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-05-13 09:29:25.546 with transit time 736 d
# Found Earth-Jupiter transit with DV 9117.22 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-05-20 09:29:25.546 with transit time 743 d
# Found Earth-Jupiter transit with DV 9125.76 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-05-27 09:29:25.546 with transit time 750 d
# Found Earth-Jupiter transit with DV 9137.56 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-06-03 09:29:25.546 with transit time 757 d
# Found Earth-Jupiter transit with DV 9153.00 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-06-10 09:29:25.546 with transit time 764 d
# Found Earth-Jupiter transit with DV 9172.58 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-06-17 09:29:25.546 with transit time 771 d
# Found Earth-Jupiter transit with DV 9196.88 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-06-24 09:29:25.546 with transit time 778 d
# Found Earth-Jupiter transit with DV 9226.64 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-07-01 09:29:25.546 with transit time 785 d
# Found Earth-Jupiter transit with DV 9262.76 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-07-08 09:29:25.546 with transit time 792 d
# Found Earth-Jupiter transit with DV 9306.39 km / s on launch 2033-05-07 09:29:25.546 arriving 2035-07-15 09:29:25.546 with transit time 799 d
# Found Earth-Jupiter transit with DV 9993.68 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-02-03 01:29:25.546 with transit time 589 d
# Found Earth-Jupiter transit with DV 9960.80 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-02-10 01:29:25.546 with transit time 596 d
# Found Earth-Jupiter transit with DV 9929.02 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-02-17 01:29:25.546 with transit time 603 d
# Found Earth-Jupiter transit with DV 9898.26 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-02-24 01:29:25.546 with transit time 610 d
# Found Earth-Jupiter transit with DV 9868.42 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-03-02 01:29:25.546 with transit time 617 d
# Found Earth-Jupiter transit with DV 9839.44 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-03-09 01:29:25.546 with transit time 624 d
# Found Earth-Jupiter transit with DV 9811.25 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-03-16 01:29:25.546 with transit time 631 d
# Found Earth-Jupiter transit with DV 9783.79 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-03-23 01:29:25.546 with transit time 638 d
# Found Earth-Jupiter transit with DV 9757.01 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-03-30 01:29:25.546 with transit time 645 d
# Found Earth-Jupiter transit with DV 9730.86 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-04-06 01:29:25.546 with transit time 652 d
# Found Earth-Jupiter transit with DV 9705.29 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-04-13 01:29:25.546 with transit time 659 d
# Found Earth-Jupiter transit with DV 9680.26 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-04-20 01:29:25.546 with transit time 666 d
# Found Earth-Jupiter transit with DV 9655.74 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-04-27 01:29:25.546 with transit time 673 d
# Found Earth-Jupiter transit with DV 9631.70 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-05-04 01:29:25.546 with transit time 680 d
# Found Earth-Jupiter transit with DV 9608.11 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-05-11 01:29:25.546 with transit time 687 d
# Found Earth-Jupiter transit with DV 9584.94 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-05-18 01:29:25.546 with transit time 694 d
# Found Earth-Jupiter transit with DV 9562.17 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-05-25 01:29:25.546 with transit time 701 d
# Found Earth-Jupiter transit with DV 9539.80 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-06-01 01:29:25.546 with transit time 708 d
# Found Earth-Jupiter transit with DV 9517.79 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-06-08 01:29:25.546 with transit time 715 d
# Found Earth-Jupiter transit with DV 9496.14 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-06-15 01:29:25.546 with transit time 722 d
# Found Earth-Jupiter transit with DV 9474.83 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-06-22 01:29:25.546 with transit time 729 d
# Found Earth-Jupiter transit with DV 9453.87 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-06-29 01:29:25.546 with transit time 736 d
# Found Earth-Jupiter transit with DV 9433.24 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-07-06 01:29:25.546 with transit time 743 d
# Found Earth-Jupiter transit with DV 9412.95 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-07-13 01:29:25.546 with transit time 750 d
# Found Earth-Jupiter transit with DV 9392.98 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-07-20 01:29:25.546 with transit time 757 d
# Found Earth-Jupiter transit with DV 9373.34 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-07-27 01:29:25.546 with transit time 764 d
# Found Earth-Jupiter transit with DV 9354.04 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-08-03 01:29:25.546 with transit time 771 d
# Found Earth-Jupiter transit with DV 9335.07 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-08-10 01:29:25.546 with transit time 778 d
# Found Earth-Jupiter transit with DV 9316.45 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-08-17 01:29:25.546 with transit time 785 d
# Found Earth-Jupiter transit with DV 9298.18 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-08-24 01:29:25.546 with transit time 792 d
# Found Earth-Jupiter transit with DV 9280.27 km / s on launch 2034-06-24 01:29:25.546 arriving 2036-08-31 01:29:25.546 with transit time 799 d
# Found Earth-Jupiter transit with DV 9970.34 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-03-26 05:07:36.455 with transit time 631 d
# Found Earth-Jupiter transit with DV 9929.61 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-04-02 05:07:36.455 with transit time 638 d
# Found Earth-Jupiter transit with DV 9891.37 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-04-09 05:07:36.455 with transit time 645 d
# Found Earth-Jupiter transit with DV 9855.49 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-04-16 05:07:36.455 with transit time 652 d
# Found Earth-Jupiter transit with DV 9821.89 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-04-23 05:07:36.455 with transit time 659 d
# Found Earth-Jupiter transit with DV 9790.44 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-04-30 05:07:36.455 with transit time 666 d
# Found Earth-Jupiter transit with DV 9761.07 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-05-07 05:07:36.455 with transit time 673 d
# Found Earth-Jupiter transit with DV 9733.67 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-05-14 05:07:36.455 with transit time 680 d
# Found Earth-Jupiter transit with DV 9708.14 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-05-21 05:07:36.455 with transit time 687 d
# Found Earth-Jupiter transit with DV 9684.41 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-05-28 05:07:36.455 with transit time 694 d
# Found Earth-Jupiter transit with DV 9662.36 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-06-04 05:07:36.455 with transit time 701 d
# Found Earth-Jupiter transit with DV 9641.90 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-06-11 05:07:36.455 with transit time 708 d
# Found Earth-Jupiter transit with DV 9622.90 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-06-18 05:07:36.455 with transit time 715 d
# Found Earth-Jupiter transit with DV 9605.25 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-06-25 05:07:36.455 with transit time 722 d
# Found Earth-Jupiter transit with DV 9588.77 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-07-02 05:07:36.455 with transit time 729 d
# Found Earth-Jupiter transit with DV 9573.27 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-07-09 05:07:36.455 with transit time 736 d
# Found Earth-Jupiter transit with DV 9558.54 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-07-16 05:07:36.455 with transit time 743 d
# Found Earth-Jupiter transit with DV 9544.69 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-07-23 05:07:36.455 with transit time 750 d
# Found Earth-Jupiter transit with DV 9535.01 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-07-30 05:07:36.455 with transit time 757 d
# Found Earth-Jupiter transit with DV 9585.47 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-08-06 05:07:36.455 with transit time 764 d
# Found Earth-Jupiter transit with DV 9790.83 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-08-20 05:07:36.455 with transit time 778 d
# Found Earth-Jupiter transit with DV 9641.30 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-08-27 05:07:36.455 with transit time 785 d
# Found Earth-Jupiter transit with DV 9600.94 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-09-03 05:07:36.455 with transit time 792 d
# Found Earth-Jupiter transit with DV 9583.32 km / s on launch 2035-07-04 05:07:36.455 arriving 2037-09-10 05:07:36.455 with transit time 799 d
# Found Earth-Jupiter transit with DV 9959.28 km / s on launch 2036-08-19 21:07:36.455 arriving 2038-03-17 21:07:36.455 with transit time 575 d
# Viable assist at 2038-03-17 21:07:36.455 with Jupiter (♃) to Saturn (♄) arrving at 2040-03-31 21:07:36.455.
# Scanned over 3431 trajectories from Earth (♁) to Jupiter (♃)
# Found 139 viable ejects from Earth to Jupiter for Titan IV
# Found 1 viable 1st assists from Jupiter to Saturn
# Found 0 viable 2nd assists from Saturn to Uranus
# Found 1 grand tour!

# %%
plotter = StaticOrbitPlotter(dark=True)
print(planet_order)
# Plot all voyager orbits
# print(voyager_orbits)

# Plot all planet orbits at encounter times
for i, po in enumerate(planet_orbits):
    plotter.plot(po, label=f"{planet_order[i].name} orbit")
    

for i, vo in enumerate(voyager_orbits):
    # print(vo)
    plotter.plot(vo, label=f"Transit between {planet_order[i].name} and {planet_order[i+1].name}")
    # print(f"Transit between {planet_order[i].name} and {planet_order[i+1].name}'}")


# Get the matplotlib Axes (poliastro versions differ: ax vs _ax)
ax = getattr(plotter, "ax", None) or plotter._ax

# Example: zoom to a +/- 5e8 km box around (0,0)
range=5e9
ax.set_xlim(-range, range)
ax.set_ylim(-range, range)
ax.set_aspect("equal", adjustable="box")

plt.show()
# Out:
# [Earth (♁), Jupiter (♃), Saturn (♄)]

# %%
# 1977-09-01 18:43:24.514 1979-06-22 18:43:24.514 11889.144703103324 km / s
time_1 = time.Time("1977-08-20 18:43:24.514", scale="utc").tdb
time_2 = time.Time("1979-06-09 18:43:24.514", scale="utc").tdb
time_3 = time.Time("1994-08-25 04:00:00", scale="utc").tdb

ephem_earth = Ephem.from_body(Earth, time_range(time_1, end=time_2), plane=Planes.EARTH_ECLIPTIC)
ephem_jupiter = Ephem.from_body(Jupiter, time_range(time_1, end=time_2), plane=Planes.EARTH_ECLIPTIC)


earth_orb = Orbit.from_ephem(Sun, ephem_earth, time_1)
jupiter_orb = Orbit.from_ephem(Sun, ephem_jupiter, time_2)
man_lambert = Maneuver.lambert(earth_orb, jupiter_orb)      
ej_dv= np.linalg.norm(man_lambert[0][1].value)
print(ej_dv*u.km/u.s)
# Out:
# 10034.059925508496 km / s
